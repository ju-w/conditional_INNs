# %%
def count_para(model):
    trainable_parameters = list(filter(lambda p: p.requires_grad, model.parameters()))
    n_trainable_parameters = sum([p.numel() for p in trainable_parameters])
    return n_trainable_parameters

# %%
import os
os.chdir('/home/students/wittmann/jw-dir/repos/conditional_INNs/colorization_cINN')

# %%
import FrEIA
from model_no_cond import *
# Out:
# /work/local/venv9/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "

# %%
print(count_para(combined_model.inn), 'inn parameters')
print(count_para(combined_model.feature_network), 'feature parameters')
print(count_para(combined_model), 'total parameters')


print(list(combined_model.inn.modules()).__len__(), 'modules')
print(list(x for x in combined_model.inn.modules() if isinstance(x, (FrEIA.modules.coupling_layers._BaseCouplingBlock, subnet_coupling_layer))).__len__(), 'coupling layers')

print(list(count_para(x) for x in list(x for x in combined_model.inn.modules() if isinstance(x, (FrEIA.modules.coupling_layers._BaseCouplingBlock, subnet_coupling_layer)))))

print((combined_model.inn.dims_in), 'input')
print((combined_model.inn.dims_c), 'cond')
# Out:
# 59102032 inn parameters
# 10 feature parameters
# 59102042 total parameters
# 607 modules
# 38 coupling layers
# [29508, 29508, 29508, 29508, 10000, 10000, 161552, 161552, 161552, 161552, 161552, 161552, 45632, 45632, 940576, 940576, 940576, 940576, 940576, 940576, 181376, 181376, 6120512, 6120512, 6120512, 6120512, 6120512, 6120512, 230656, 230656, 1839104, 1839104, 1839104, 1839104, 1839104, 1839104, 1839104, 1839104]
# [(2, 64, 64)] input
# [(1, 64, 64)] cond

# %%
list(x.shape for x in combined_model.inn(torch.rand(7, 2, 64, 64), torch.rand(7, 1,256,256))[0])
# Out:
# [torch.Size([7, 4096]),
#  torch.Size([7, 2048]),
#  torch.Size([7, 1536]),
#  torch.Size([7, 512])]

# %%
list(x.shape for x in combined_model(torch.rand(7,3,256,256)))
# Out:
# [torch.Size([7]), torch.Size([7])]

# %%
for x in combined_model.inn.node_list_fwd:
    print(x, x.conditions, x.condition_dims)
# Out:
# ConditionNode 'fd67e0': [] ->  -> [(1, 64, 64)] [] []
# InputNode 'inp': [] ->  -> [(2, 64, 64)] [] []
# Node 'conv_0': [(2, 64, 64)] -> subnet_coupling_layer -> [(2, 64, 64)] [(ConditionNode 'fd67e0', 0)] [(1, 64, 64)]
# Node 'f857c0': [(2, 64, 64)] -> Fixed1x1Conv -> [(2, 64, 64)] [] []
# Node 'conv_1': [(2, 64, 64)] -> subnet_coupling_layer -> [(2, 64, 64)] [(ConditionNode 'fd67e0', 0)] [(1, 64, 64)]
# Node 'e5f590': [(2, 64, 64)] -> Fixed1x1Conv -> [(2, 64, 64)] [] []
# Node 'conv_2': [(2, 64, 64)] -> subnet_coupling_layer -> [(2, 64, 64)] [(ConditionNode 'fd67e0', 0)] [(1, 64, 64)]
# Node 'e5f920': [(2, 64, 64)] -> Fixed1x1Conv -> [(2, 64, 64)] [] []
# Node 'conv_3': [(2, 64, 64)] -> subnet_coupling_layer -> [(2, 64, 64)] [(ConditionNode 'fd67e0', 0)] [(1, 64, 64)]
# Node 'e5fc80': [(2, 64, 64)] -> Fixed1x1Conv -> [(2, 64, 64)] [] []
# Node 'reshape': [(2, 64, 64)] -> IRevNetDownsampling -> ((8, 32, 32),) [] []
# Node 'e5fd40': [(8, 32, 32)] -> Fixed1x1Conv -> [(8, 32, 32)] [] []
# Node 'e5fe30': [(8, 32, 32)] -> GLOWCouplingBlock -> [(8, 32, 32)] [] []
# Node 'e5fe00': [(8, 32, 32)] -> Fixed1x1Conv -> [(8, 32, 32)] [] []
# Node 'eb80e0': [(8, 32, 32)] -> GLOWCouplingBlock -> [(8, 32, 32)] [] []
# Node 'conv_0': [(8, 32, 32)] -> subnet_coupling_layer -> [(8, 32, 32)] [(ConditionNode 'fd67e0', 0)] [(1, 64, 64)]
# Node 'eb8620': [(8, 32, 32)] -> Fixed1x1Conv -> [(8, 32, 32)] [] []
# Node 'conv_1': [(8, 32, 32)] -> subnet_coupling_layer -> [(8, 32, 32)] [(ConditionNode 'fd67e0', 0)] [(1, 64, 64)]
# Node 'eb8a10': [(8, 32, 32)] -> Fixed1x1Conv -> [(8, 32, 32)] [] []
# Node 'conv_2': [(8, 32, 32)] -> subnet_coupling_layer -> [(8, 32, 32)] [(ConditionNode 'fd67e0', 0)] [(1, 64, 64)]
# Node 'eb8dd0': [(8, 32, 32)] -> Fixed1x1Conv -> [(8, 32, 32)] [] []
# Node 'conv_3': [(8, 32, 32)] -> subnet_coupling_layer -> [(8, 32, 32)] [(ConditionNode 'fd67e0', 0)] [(1, 64, 64)]
# Node 'eb9190': [(8, 32, 32)] -> Fixed1x1Conv -> [(8, 32, 32)] [] []
# Node 'conv_4': [(8, 32, 32)] -> subnet_coupling_layer -> [(8, 32, 32)] [(ConditionNode 'fd67e0', 0)] [(1, 64, 64)]
# Node 'eb9580': [(8, 32, 32)] -> Fixed1x1Conv -> [(8, 32, 32)] [] []
# Node 'conv_5': [(8, 32, 32)] -> subnet_coupling_layer -> [(8, 32, 32)] [(ConditionNode 'fd67e0', 0)] [(1, 64, 64)]
# Node 'eb9940': [(8, 32, 32)] -> Fixed1x1Conv -> [(8, 32, 32)] [] []
# Node 'reshape': [(8, 32, 32)] -> IRevNetDownsampling -> ((32, 16, 16),) [] []
# Node 'eb9a00': [(32, 16, 16)] -> Fixed1x1Conv -> [(32, 16, 16)] [] []
# Node 'eb9af0': [(32, 16, 16)] -> GLOWCouplingBlock -> [(32, 16, 16)] [] []
# Node 'eb9ac0': [(32, 16, 16)] -> Fixed1x1Conv -> [(32, 16, 16)] [] []
# Node 'eb9d90': [(32, 16, 16)] -> GLOWCouplingBlock -> [(32, 16, 16)] [] []
# Node 'split': [(32, 16, 16)] -> Split -> [(16, 16, 16), (16, 16, 16)] [] []
# Node 'conv_0': [(16, 16, 16)] -> subnet_coupling_layer -> [(16, 16, 16)] [(ConditionNode 'fd67e0', 0)] [(1, 64, 64)]
# Node 'eba3f0': [(16, 16, 16)] -> Fixed1x1Conv -> [(16, 16, 16)] [] []
# Node 'conv_1': [(16, 16, 16)] -> subnet_coupling_layer -> [(16, 16, 16)] [(ConditionNode 'fd67e0', 0)] [(1, 64, 64)]
# Node 'eba840': [(16, 16, 16)] -> Fixed1x1Conv -> [(16, 16, 16)] [] []
# Node 'conv_2': [(16, 16, 16)] -> subnet_coupling_layer -> [(16, 16, 16)] [(ConditionNode 'fd67e0', 0)] [(1, 64, 64)]
# Node 'ebac90': [(16, 16, 16)] -> Fixed1x1Conv -> [(16, 16, 16)] [] []
# Node 'conv_3': [(16, 16, 16)] -> subnet_coupling_layer -> [(16, 16, 16)] [(ConditionNode 'fd67e0', 0)] [(1, 64, 64)]
# Node 'ebb0e0': [(16, 16, 16)] -> Fixed1x1Conv -> [(16, 16, 16)] [] []
# Node 'conv_4': [(16, 16, 16)] -> subnet_coupling_layer -> [(16, 16, 16)] [(ConditionNode 'fd67e0', 0)] [(1, 64, 64)]
# Node 'ebb530': [(16, 16, 16)] -> Fixed1x1Conv -> [(16, 16, 16)] [] []
# Node 'conv_5': [(16, 16, 16)] -> subnet_coupling_layer -> [(16, 16, 16)] [(ConditionNode 'fd67e0', 0)] [(1, 64, 64)]
# Node 'ebb980': [(16, 16, 16)] -> Fixed1x1Conv -> [(16, 16, 16)] [] []
# Node 'reshape': [(16, 16, 16)] -> IRevNetDownsampling -> ((64, 8, 8),) [] []
# Node 'ebba40': [(64, 8, 8)] -> Fixed1x1Conv -> [(64, 8, 8)] [] []
# Node 'ebbb30': [(64, 8, 8)] -> GLOWCouplingBlock -> [(64, 8, 8)] [] []
# Node 'ebbb00': [(64, 8, 8)] -> Fixed1x1Conv -> [(64, 8, 8)] [] []
# Node 'ebbdd0': [(64, 8, 8)] -> GLOWCouplingBlock -> [(64, 8, 8)] [] []
# Node 'split': [(64, 8, 8)] -> Split -> [(32, 8, 8), (32, 8, 8)] [] []
# Node 'conv_0': [(32, 8, 8)] -> subnet_coupling_layer -> [(32, 8, 8)] [(ConditionNode 'fd67e0', 0)] [(1, 64, 64)]
# Node '8a4500': [(32, 8, 8)] -> Fixed1x1Conv -> [(32, 8, 8)] [] []
# Node 'conv_1': [(32, 8, 8)] -> subnet_coupling_layer -> [(32, 8, 8)] [(ConditionNode 'fd67e0', 0)] [(1, 64, 64)]
# Node '8a49b0': [(32, 8, 8)] -> Fixed1x1Conv -> [(32, 8, 8)] [] []
# Node 'conv_2': [(32, 8, 8)] -> subnet_coupling_layer -> [(32, 8, 8)] [(ConditionNode 'fd67e0', 0)] [(1, 64, 64)]
# Node '8a4e60': [(32, 8, 8)] -> Fixed1x1Conv -> [(32, 8, 8)] [] []
# Node 'conv_3': [(32, 8, 8)] -> subnet_coupling_layer -> [(32, 8, 8)] [(ConditionNode 'fd67e0', 0)] [(1, 64, 64)]
# Node '8a5310': [(32, 8, 8)] -> Fixed1x1Conv -> [(32, 8, 8)] [] []
# Node 'conv_4': [(32, 8, 8)] -> subnet_coupling_layer -> [(32, 8, 8)] [(ConditionNode 'fd67e0', 0)] [(1, 64, 64)]
# Node '8a5790': [(32, 8, 8)] -> Fixed1x1Conv -> [(32, 8, 8)] [] []
# Node 'conv_5': [(32, 8, 8)] -> subnet_coupling_layer -> [(32, 8, 8)] [(ConditionNode 'fd67e0', 0)] [(1, 64, 64)]
# Node '8a5c40': [(32, 8, 8)] -> Fixed1x1Conv -> [(32, 8, 8)] [] []
# Node 'haar': [(32, 8, 8)] -> HaarDownsampling -> ((128, 4, 4),) [] []
# Node '8a5d00': [(128, 4, 4)] -> Fixed1x1Conv -> [(128, 4, 4)] [] []
# Node '8a5df0': [(128, 4, 4)] -> GLOWCouplingBlock -> [(128, 4, 4)] [] []
# Node '8a5dc0': [(128, 4, 4)] -> Fixed1x1Conv -> [(128, 4, 4)] [] []
# Node '8a6090': [(128, 4, 4)] -> GLOWCouplingBlock -> [(128, 4, 4)] [] []
# Node 'split': [(128, 4, 4)] -> Split -> [(32, 4, 4), (96, 4, 4)] [] []
# Node 'flatten': [(32, 4, 4)] -> Flatten -> ((512,),) [] []
# Node 'permute_0': [(512,)] -> PermuteRandom -> [(512,)] [] []
# Node 'fc_0': [(512,)] -> GLOWCouplingBlock -> [(512,)] [] []
# Node 'permute_1': [(512,)] -> PermuteRandom -> [(512,)] [] []
# Node 'fc_1': [(512,)] -> GLOWCouplingBlock -> [(512,)] [] []
# Node 'permute_2': [(512,)] -> PermuteRandom -> [(512,)] [] []
# Node 'fc_2': [(512,)] -> GLOWCouplingBlock -> [(512,)] [] []
# Node 'permute_3': [(512,)] -> PermuteRandom -> [(512,)] [] []
# Node 'fc_3': [(512,)] -> GLOWCouplingBlock -> [(512,)] [] []
# Node 'permute_4': [(512,)] -> PermuteRandom -> [(512,)] [] []
# Node 'fc_4': [(512,)] -> GLOWCouplingBlock -> [(512,)] [] []
# Node 'permute_5': [(512,)] -> PermuteRandom -> [(512,)] [] []
# Node 'fc_5': [(512,)] -> GLOWCouplingBlock -> [(512,)] [] []
# Node 'permute_6': [(512,)] -> PermuteRandom -> [(512,)] [] []
# Node 'fc_6': [(512,)] -> GLOWCouplingBlock -> [(512,)] [] []
# Node 'permute_7': [(512,)] -> PermuteRandom -> [(512,)] [] []
# Node 'fc_7': [(512,)] -> GLOWCouplingBlock -> [(512,)] [] []
# Node 'flatten': [(96, 4, 4)] -> Flatten -> ((1536,),) [] []
# Node 'flatten': [(32, 8, 8)] -> Flatten -> ((2048,),) [] []
# Node 'flatten': [(16, 16, 16)] -> Flatten -> ((4096,),) [] []
# OutputNode 'out': [(512,)] ->  -> [] [] []
# OutputNode 'out': [(1536,)] ->  -> [] [] []
# OutputNode 'out': [(2048,)] ->  -> [] [] []
# OutputNode 'out': [(4096,)] ->  -> [] [] []

# %%
combined_model
# Out:
# WrappedModel(
#   (feature_network): DummyFeatureNet()
#   (inn): ReversibleGraphNet(
#     (module_list): ModuleList(
#       (0): subnet_coupling_layer(
#         (subnet): Sequential(
#           (0): HaarConv()
#           (1): HaarConv()
#         )
#         (s1): F_conv(
#           (conv1): Conv2d(17, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(32, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (s2): F_conv(
#           (conv1): Conv2d(17, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(32, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (1): Fixed1x1Conv()
#       (2): subnet_coupling_layer(
#         (subnet): Sequential(
#           (0): HaarConv()
#           (1): HaarConv()
#         )
#         (s1): F_conv(
#           (conv1): Conv2d(17, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(32, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (s2): F_conv(
#           (conv1): Conv2d(17, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(32, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (3): Fixed1x1Conv()
#       (4): subnet_coupling_layer(
#         (subnet): Sequential(
#           (0): HaarConv()
#           (1): HaarConv()
#         )
#         (s1): F_conv(
#           (conv1): Conv2d(17, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(32, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (s2): F_conv(
#           (conv1): Conv2d(17, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(32, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (5): Fixed1x1Conv()
#       (6): subnet_coupling_layer(
#         (subnet): Sequential(
#           (0): HaarConv()
#           (1): HaarConv()
#         )
#         (s1): F_conv(
#           (conv1): Conv2d(17, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(32, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (s2): F_conv(
#           (conv1): Conv2d(17, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(32, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (7): Fixed1x1Conv()
#       (8): IRevNetDownsampling()
#       (9): Fixed1x1Conv()
#       (10): GLOWCouplingBlock(
#         (subnet1): F_conv(
#           (conv1): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#           (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           (conv3): Conv2d(64, 8, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (subnet2): F_conv(
#           (conv1): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#           (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           (conv3): Conv2d(64, 8, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (11): Fixed1x1Conv()
#       (12): GLOWCouplingBlock(
#         (subnet1): F_conv(
#           (conv1): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#           (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           (conv3): Conv2d(64, 8, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (subnet2): F_conv(
#           (conv1): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#           (conv2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           (conv3): Conv2d(64, 8, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (13): subnet_coupling_layer(
#         (subnet): Sequential(
#           (0): HaarConv()
#           (1): HaarConv()
#           (2): HaarConv()
#         )
#         (s1): F_conv(
#           (conv1): Conv2d(68, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(64, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (s2): F_conv(
#           (conv1): Conv2d(68, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(64, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (14): Fixed1x1Conv()
#       (15): subnet_coupling_layer(
#         (subnet): Sequential(
#           (0): HaarConv()
#           (1): HaarConv()
#           (2): HaarConv()
#         )
#         (s1): F_conv(
#           (conv1): Conv2d(68, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(64, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (s2): F_conv(
#           (conv1): Conv2d(68, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(64, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (16): Fixed1x1Conv()
#       (17): subnet_coupling_layer(
#         (subnet): Sequential(
#           (0): HaarConv()
#           (1): HaarConv()
#           (2): HaarConv()
#         )
#         (s1): F_conv(
#           (conv1): Conv2d(68, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(64, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (s2): F_conv(
#           (conv1): Conv2d(68, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(64, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (18): Fixed1x1Conv()
#       (19): subnet_coupling_layer(
#         (subnet): Sequential(
#           (0): HaarConv()
#           (1): HaarConv()
#           (2): HaarConv()
#         )
#         (s1): F_conv(
#           (conv1): Conv2d(68, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(64, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (s2): F_conv(
#           (conv1): Conv2d(68, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(64, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (20): Fixed1x1Conv()
#       (21): subnet_coupling_layer(
#         (subnet): Sequential(
#           (0): HaarConv()
#           (1): HaarConv()
#           (2): HaarConv()
#         )
#         (s1): F_conv(
#           (conv1): Conv2d(68, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(64, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (s2): F_conv(
#           (conv1): Conv2d(68, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(64, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (22): Fixed1x1Conv()
#       (23): subnet_coupling_layer(
#         (subnet): Sequential(
#           (0): HaarConv()
#           (1): HaarConv()
#           (2): HaarConv()
#         )
#         (s1): F_conv(
#           (conv1): Conv2d(68, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(64, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (s2): F_conv(
#           (conv1): Conv2d(68, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(64, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (24): Fixed1x1Conv()
#       (25): IRevNetDownsampling()
#       (26): Fixed1x1Conv()
#       (27): GLOWCouplingBlock(
#         (subnet1): F_conv(
#           (conv1): Conv2d(16, 128, kernel_size=(1, 1), stride=(1, 1))
#           (conv2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (subnet2): F_conv(
#           (conv1): Conv2d(16, 128, kernel_size=(1, 1), stride=(1, 1))
#           (conv2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (28): Fixed1x1Conv()
#       (29): Flatten()
#       (30): GLOWCouplingBlock(
#         (subnet1): F_conv(
#           (conv1): Conv2d(16, 128, kernel_size=(1, 1), stride=(1, 1))
#           (conv2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (subnet2): F_conv(
#           (conv1): Conv2d(16, 128, kernel_size=(1, 1), stride=(1, 1))
#           (conv2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#           (conv3): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (31): Split()
#       (32): subnet_coupling_layer(
#         (subnet): Sequential(
#           (0): HaarConv()
#           (1): HaarConv()
#           (2): HaarConv()
#           (3): HaarConv()
#         )
#         (s1): F_conv(
#           (conv1): Conv2d(264, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (s2): F_conv(
#           (conv1): Conv2d(264, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (33): Fixed1x1Conv()
#       (34): subnet_coupling_layer(
#         (subnet): Sequential(
#           (0): HaarConv()
#           (1): HaarConv()
#           (2): HaarConv()
#           (3): HaarConv()
#         )
#         (s1): F_conv(
#           (conv1): Conv2d(264, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (s2): F_conv(
#           (conv1): Conv2d(264, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (35): Fixed1x1Conv()
#       (36): subnet_coupling_layer(
#         (subnet): Sequential(
#           (0): HaarConv()
#           (1): HaarConv()
#           (2): HaarConv()
#           (3): HaarConv()
#         )
#         (s1): F_conv(
#           (conv1): Conv2d(264, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (s2): F_conv(
#           (conv1): Conv2d(264, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (37): Fixed1x1Conv()
#       (38): subnet_coupling_layer(
#         (subnet): Sequential(
#           (0): HaarConv()
#           (1): HaarConv()
#           (2): HaarConv()
#           (3): HaarConv()
#         )
#         (s1): F_conv(
#           (conv1): Conv2d(264, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (s2): F_conv(
#           (conv1): Conv2d(264, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (39): Fixed1x1Conv()
#       (40): subnet_coupling_layer(
#         (subnet): Sequential(
#           (0): HaarConv()
#           (1): HaarConv()
#           (2): HaarConv()
#           (3): HaarConv()
#         )
#         (s1): F_conv(
#           (conv1): Conv2d(264, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (s2): F_conv(
#           (conv1): Conv2d(264, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (41): Fixed1x1Conv()
#       (42): subnet_coupling_layer(
#         (subnet): Sequential(
#           (0): HaarConv()
#           (1): HaarConv()
#           (2): HaarConv()
#           (3): HaarConv()
#         )
#         (s1): F_conv(
#           (conv1): Conv2d(264, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (s2): F_conv(
#           (conv1): Conv2d(264, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(128, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (43): Fixed1x1Conv()
#       (44): IRevNetDownsampling()
#       (45): Fixed1x1Conv()
#       (46): GLOWCouplingBlock(
#         (subnet1): F_conv(
#           (conv1): Conv2d(32, 256, kernel_size=(1, 1), stride=(1, 1))
#           (conv2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#           (conv3): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (subnet2): F_conv(
#           (conv1): Conv2d(32, 256, kernel_size=(1, 1), stride=(1, 1))
#           (conv2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#           (conv3): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (47): Fixed1x1Conv()
#       (48): Flatten()
#       (49): GLOWCouplingBlock(
#         (subnet1): F_conv(
#           (conv1): Conv2d(32, 256, kernel_size=(1, 1), stride=(1, 1))
#           (conv2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#           (conv3): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (subnet2): F_conv(
#           (conv1): Conv2d(32, 256, kernel_size=(1, 1), stride=(1, 1))
#           (conv2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#           (conv3): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (50): Split()
#       (51): subnet_coupling_layer(
#         (subnet): Sequential(
#           (0): HaarConv()
#           (1): HaarConv()
#           (2): HaarConv()
#           (3): HaarConv()
#           (4): HaarConv()
#         )
#         (s1): F_conv(
#           (conv1): Conv2d(1040, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(256, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (s2): F_conv(
#           (conv1): Conv2d(1040, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(256, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (52): Fixed1x1Conv()
#       (53): subnet_coupling_layer(
#         (subnet): Sequential(
#           (0): HaarConv()
#           (1): HaarConv()
#           (2): HaarConv()
#           (3): HaarConv()
#           (4): HaarConv()
#         )
#         (s1): F_conv(
#           (conv1): Conv2d(1040, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(256, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (s2): F_conv(
#           (conv1): Conv2d(1040, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(256, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (54): Fixed1x1Conv()
#       (55): subnet_coupling_layer(
#         (subnet): Sequential(
#           (0): HaarConv()
#           (1): HaarConv()
#           (2): HaarConv()
#           (3): HaarConv()
#           (4): HaarConv()
#         )
#         (s1): F_conv(
#           (conv1): Conv2d(1040, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(256, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (s2): F_conv(
#           (conv1): Conv2d(1040, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(256, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (56): Fixed1x1Conv()
#       (57): subnet_coupling_layer(
#         (subnet): Sequential(
#           (0): HaarConv()
#           (1): HaarConv()
#           (2): HaarConv()
#           (3): HaarConv()
#           (4): HaarConv()
#         )
#         (s1): F_conv(
#           (conv1): Conv2d(1040, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(256, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (s2): F_conv(
#           (conv1): Conv2d(1040, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(256, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (58): Fixed1x1Conv()
#       (59): subnet_coupling_layer(
#         (subnet): Sequential(
#           (0): HaarConv()
#           (1): HaarConv()
#           (2): HaarConv()
#           (3): HaarConv()
#           (4): HaarConv()
#         )
#         (s1): F_conv(
#           (conv1): Conv2d(1040, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(256, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (s2): F_conv(
#           (conv1): Conv2d(1040, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(256, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (60): Fixed1x1Conv()
#       (61): subnet_coupling_layer(
#         (subnet): Sequential(
#           (0): HaarConv()
#           (1): HaarConv()
#           (2): HaarConv()
#           (3): HaarConv()
#           (4): HaarConv()
#         )
#         (s1): F_conv(
#           (conv1): Conv2d(1040, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(256, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (s2): F_conv(
#           (conv1): Conv2d(1040, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (conv3): Conv2d(256, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (62): Fixed1x1Conv()
#       (63): HaarDownsampling()
#       (64): Fixed1x1Conv()
#       (65): GLOWCouplingBlock(
#         (subnet1): F_conv(
#           (conv1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#           (conv2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#           (conv3): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (subnet2): F_conv(
#           (conv1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#           (conv2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#           (conv3): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (66): Fixed1x1Conv()
#       (67): Flatten()
#       (68): GLOWCouplingBlock(
#         (subnet1): F_conv(
#           (conv1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#           (conv2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#           (conv3): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (subnet2): F_conv(
#           (conv1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#           (conv2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#           (conv3): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (69): Split()
#       (70): Flatten()
#       (71): PermuteRandom()
#       (72): GLOWCouplingBlock(
#         (subnet1): F_fully_connected(
#           (d1): Dropout(p=0.0, inplace=False)
#           (d2): Dropout(p=0.0, inplace=False)
#           (d2b): Dropout(p=0.0, inplace=False)
#           (fc1): Linear(in_features=256, out_features=512, bias=True)
#           (fc2): Linear(in_features=512, out_features=512, bias=True)
#           (fc2b): Linear(in_features=512, out_features=512, bias=True)
#           (fc3): Linear(in_features=512, out_features=512, bias=True)
#           (nl1): ReLU()
#           (nl2): ReLU()
#           (nl2b): ReLU()
#         )
#         (subnet2): F_fully_connected(
#           (d1): Dropout(p=0.0, inplace=False)
#           (d2): Dropout(p=0.0, inplace=False)
#           (d2b): Dropout(p=0.0, inplace=False)
#           (fc1): Linear(in_features=256, out_features=512, bias=True)
#           (fc2): Linear(in_features=512, out_features=512, bias=True)
#           (fc2b): Linear(in_features=512, out_features=512, bias=True)
#           (fc3): Linear(in_features=512, out_features=512, bias=True)
#           (nl1): ReLU()
#           (nl2): ReLU()
#           (nl2b): ReLU()
#         )
#       )
#       (73): PermuteRandom()
#       (74): GLOWCouplingBlock(
#         (subnet1): F_fully_connected(
#           (d1): Dropout(p=0.0, inplace=False)
#           (d2): Dropout(p=0.0, inplace=False)
#           (d2b): Dropout(p=0.0, inplace=False)
#           (fc1): Linear(in_features=256, out_features=512, bias=True)
#           (fc2): Linear(in_features=512, out_features=512, bias=True)
#           (fc2b): Linear(in_features=512, out_features=512, bias=True)
#           (fc3): Linear(in_features=512, out_features=512, bias=True)
#           (nl1): ReLU()
#           (nl2): ReLU()
#           (nl2b): ReLU()
#         )
#         (subnet2): F_fully_connected(
#           (d1): Dropout(p=0.0, inplace=False)
#           (d2): Dropout(p=0.0, inplace=False)
#           (d2b): Dropout(p=0.0, inplace=False)
#           (fc1): Linear(in_features=256, out_features=512, bias=True)
#           (fc2): Linear(in_features=512, out_features=512, bias=True)
#           (fc2b): Linear(in_features=512, out_features=512, bias=True)
#           (fc3): Linear(in_features=512, out_features=512, bias=True)
#           (nl1): ReLU()
#           (nl2): ReLU()
#           (nl2b): ReLU()
#         )
#       )
#       (75): PermuteRandom()
#       (76): GLOWCouplingBlock(
#         (subnet1): F_fully_connected(
#           (d1): Dropout(p=0.0, inplace=False)
#           (d2): Dropout(p=0.0, inplace=False)
#           (d2b): Dropout(p=0.0, inplace=False)
#           (fc1): Linear(in_features=256, out_features=512, bias=True)
#           (fc2): Linear(in_features=512, out_features=512, bias=True)
#           (fc2b): Linear(in_features=512, out_features=512, bias=True)
#           (fc3): Linear(in_features=512, out_features=512, bias=True)
#           (nl1): ReLU()
#           (nl2): ReLU()
#           (nl2b): ReLU()
#         )
#         (subnet2): F_fully_connected(
#           (d1): Dropout(p=0.0, inplace=False)
#           (d2): Dropout(p=0.0, inplace=False)
#           (d2b): Dropout(p=0.0, inplace=False)
#           (fc1): Linear(in_features=256, out_features=512, bias=True)
#           (fc2): Linear(in_features=512, out_features=512, bias=True)
#           (fc2b): Linear(in_features=512, out_features=512, bias=True)
#           (fc3): Linear(in_features=512, out_features=512, bias=True)
#           (nl1): ReLU()
#           (nl2): ReLU()
#           (nl2b): ReLU()
#         )
#       )
#       (77): PermuteRandom()
#       (78): GLOWCouplingBlock(
#         (subnet1): F_fully_connected(
#           (d1): Dropout(p=0.0, inplace=False)
#           (d2): Dropout(p=0.0, inplace=False)
#           (d2b): Dropout(p=0.0, inplace=False)
#           (fc1): Linear(in_features=256, out_features=512, bias=True)
#           (fc2): Linear(in_features=512, out_features=512, bias=True)
#           (fc2b): Linear(in_features=512, out_features=512, bias=True)
#           (fc3): Linear(in_features=512, out_features=512, bias=True)
#           (nl1): ReLU()
#           (nl2): ReLU()
#           (nl2b): ReLU()
#         )
#         (subnet2): F_fully_connected(
#           (d1): Dropout(p=0.0, inplace=False)
#           (d2): Dropout(p=0.0, inplace=False)
#           (d2b): Dropout(p=0.0, inplace=False)
#           (fc1): Linear(in_features=256, out_features=512, bias=True)
#           (fc2): Linear(in_features=512, out_features=512, bias=True)
#           (fc2b): Linear(in_features=512, out_features=512, bias=True)
#           (fc3): Linear(in_features=512, out_features=512, bias=True)
#           (nl1): ReLU()
#           (nl2): ReLU()
#           (nl2b): ReLU()
#         )
#       )
#       (79): PermuteRandom()
#       (80): GLOWCouplingBlock(
#         (subnet1): F_fully_connected(
#           (d1): Dropout(p=0.0, inplace=False)
#           (d2): Dropout(p=0.0, inplace=False)
#           (d2b): Dropout(p=0.0, inplace=False)
#           (fc1): Linear(in_features=256, out_features=512, bias=True)
#           (fc2): Linear(in_features=512, out_features=512, bias=True)
#           (fc2b): Linear(in_features=512, out_features=512, bias=True)
#           (fc3): Linear(in_features=512, out_features=512, bias=True)
#           (nl1): ReLU()
#           (nl2): ReLU()
#           (nl2b): ReLU()
#         )
#         (subnet2): F_fully_connected(
#           (d1): Dropout(p=0.0, inplace=False)
#           (d2): Dropout(p=0.0, inplace=False)
#           (d2b): Dropout(p=0.0, inplace=False)
#           (fc1): Linear(in_features=256, out_features=512, bias=True)
#           (fc2): Linear(in_features=512, out_features=512, bias=True)
#           (fc2b): Linear(in_features=512, out_features=512, bias=True)
#           (fc3): Linear(in_features=512, out_features=512, bias=True)
#           (nl1): ReLU()
#           (nl2): ReLU()
#           (nl2b): ReLU()
#         )
#       )
#       (81): PermuteRandom()
#       (82): GLOWCouplingBlock(
#         (subnet1): F_fully_connected(
#           (d1): Dropout(p=0.0, inplace=False)
#           (d2): Dropout(p=0.0, inplace=False)
#           (d2b): Dropout(p=0.0, inplace=False)
#           (fc1): Linear(in_features=256, out_features=512, bias=True)
#           (fc2): Linear(in_features=512, out_features=512, bias=True)
#           (fc2b): Linear(in_features=512, out_features=512, bias=True)
#           (fc3): Linear(in_features=512, out_features=512, bias=True)
#           (nl1): ReLU()
#           (nl2): ReLU()
#           (nl2b): ReLU()
#         )
#         (subnet2): F_fully_connected(
#           (d1): Dropout(p=0.0, inplace=False)
#           (d2): Dropout(p=0.0, inplace=False)
#           (d2b): Dropout(p=0.0, inplace=False)
#           (fc1): Linear(in_features=256, out_features=512, bias=True)
#           (fc2): Linear(in_features=512, out_features=512, bias=True)
#           (fc2b): Linear(in_features=512, out_features=512, bias=True)
#           (fc3): Linear(in_features=512, out_features=512, bias=True)
#           (nl1): ReLU()
#           (nl2): ReLU()
#           (nl2b): ReLU()
#         )
#       )
#       (83): PermuteRandom()
#       (84): GLOWCouplingBlock(
#         (subnet1): F_fully_connected(
#           (d1): Dropout(p=0.0, inplace=False)
#           (d2): Dropout(p=0.0, inplace=False)
#           (d2b): Dropout(p=0.0, inplace=False)
#           (fc1): Linear(in_features=256, out_features=512, bias=True)
#           (fc2): Linear(in_features=512, out_features=512, bias=True)
#           (fc2b): Linear(in_features=512, out_features=512, bias=True)
#           (fc3): Linear(in_features=512, out_features=512, bias=True)
#           (nl1): ReLU()
#           (nl2): ReLU()
#           (nl2b): ReLU()
#         )
#         (subnet2): F_fully_connected(
#           (d1): Dropout(p=0.0, inplace=False)
#           (d2): Dropout(p=0.0, inplace=False)
#           (d2b): Dropout(p=0.0, inplace=False)
#           (fc1): Linear(in_features=256, out_features=512, bias=True)
#           (fc2): Linear(in_features=512, out_features=512, bias=True)
#           (fc2b): Linear(in_features=512, out_features=512, bias=True)
#           (fc3): Linear(in_features=512, out_features=512, bias=True)
#           (nl1): ReLU()
#           (nl2): ReLU()
#           (nl2b): ReLU()
#         )
#       )
#       (85): PermuteRandom()
#       (86): GLOWCouplingBlock(
#         (subnet1): F_fully_connected(
#           (d1): Dropout(p=0.0, inplace=False)
#           (d2): Dropout(p=0.0, inplace=False)
#           (d2b): Dropout(p=0.0, inplace=False)
#           (fc1): Linear(in_features=256, out_features=512, bias=True)
#           (fc2): Linear(in_features=512, out_features=512, bias=True)
#           (fc2b): Linear(in_features=512, out_features=512, bias=True)
#           (fc3): Linear(in_features=512, out_features=512, bias=True)
#           (nl1): ReLU()
#           (nl2): ReLU()
#           (nl2b): ReLU()
#         )
#         (subnet2): F_fully_connected(
#           (d1): Dropout(p=0.0, inplace=False)
#           (d2): Dropout(p=0.0, inplace=False)
#           (d2b): Dropout(p=0.0, inplace=False)
#           (fc1): Linear(in_features=256, out_features=512, bias=True)
#           (fc2): Linear(in_features=512, out_features=512, bias=True)
#           (fc2b): Linear(in_features=512, out_features=512, bias=True)
#           (fc3): Linear(in_features=512, out_features=512, bias=True)
#           (nl1): ReLU()
#           (nl2): ReLU()
#           (nl2b): ReLU()
#         )
#       )
#     )
#   )
# )
